# %%
import numpy as np
import pickle
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

# %%
with open("sim_mat_test_no_csls.pkl", "rb") as f:
    sim_mat = pickle.load(f)

# %%
#http://dbpedia.org/resource/Michel_Temer	Michel_Temer

# %%
ent_embeds = np.load('20201110112701/ent_embeds.npy')

# %%
#http://dbpedia.org/resource/Roger_II_of_Sicily	852
#Roger_II_of_Sicily	2051

# %%
ent_embeds[852].dot(ent_embeds[2051])
# Out:
# 0.6769584

# %%
for i in tqdm(range(9000)):
    for j in range(9000):
        if (sim_mat[i][j] == 0.6769584):
            print(i,j)

# %%
for i in tqdm(range(9000)):
    for j in range(9000):
        if (abs(sim_mat[i][j] - 0.6769584) <= 0.000001):
            print(i,j)
# Out:
# ...
# 125 125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-d9dce10fdf50> in <module>
#       1 for i in tqdm(range(9000)):
#       2     for j in range(9000):
# ----> 3         if (abs(sim_mat[i][j] - 0.6769584) <= 0.000001):
#       4             print(i,j)
#
# KeyboardInterrupt:

# %%
np.max(sim_mat[125])
# Out:
# 0.67695826

# %%
ent_embeds[852].dot(ent_embeds[2051])
# Out:
# 0.6769584

# %%
np.matmul(ent_embeds[852], ent_embeds[2051].T)
# Out:
# 0.6769584

# %%
c = 0
for i in tqdm(range(9000)):
    if (sim_mat[i][i] == np.max(sim_mat[i])):
        c+=1
print(c)
# Out:
# ...
# 2384

# %%
c/9000
# Out:
# 0.2648888888888889

# %%
roger = sim_mat[125]
idx = range(0, 9000)
plt.scatter(idx, roger)

# %%
dists = []
for i in range(9000):
    temp = np.partition(-sim_mat[i], 2)
    result = -temp[:2]
    dists.append(abs(result[0] - result[1]))

# %%
plt.scatter(idx, dists)

# %%
plt.hist(dists)
# Out:
# (array([5987., 1210.,  650.,  421.,  250.,  187.,  131.,   75.,   61.,
#           28.]),
#  array([3.9041042e-06, 6.8417192e-02, 1.3683048e-01, 2.0524375e-01,
#         2.7365705e-01, 3.4207034e-01, 4.1048360e-01, 4.7889689e-01,
#         5.4731017e-01, 6.1572349e-01, 6.8413675e-01], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
maxs = []
for i in range(9000):
    maxs.append(np.max(sim_mat[i]))

# %%
plt.hist(maxs)
# Out:
# (array([1030., 1282.,  651.,  627.,  652.,  760.,  566.,  542.,  953.,
#         1937.]),
#  array([0.2770813 , 0.3493253 , 0.4215693 , 0.49381328, 0.56605726,
#         0.63830125, 0.71054524, 0.78278923, 0.8550332 , 0.9272772 ,
#         0.9995212 ], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(idx, maxs)

# %%
ids = []
for i in tqdm(range(9000)):
    if (sim_mat[i][i] == np.max(sim_mat[i])):
        ids.append(i)

# %%
maxs_corr = []
for i in ids:
    maxs_corr.append(np.max(sim_mat[i]))

# %%
plt.hist(maxs_corr)
# Out:
# (array([   6.,    9.,   22.,   35.,   60.,   71.,   37.,   81.,  562.,
#         1501.]),
#  array([0.3171292, 0.3853684, 0.4536076, 0.5218468, 0.590086 , 0.6583252,
#         0.7265644, 0.7948036, 0.8630428, 0.931282 , 0.9995212],
#        dtype=float32),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(ids, maxs_corr)
